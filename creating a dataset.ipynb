# %%
import os
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('districtwise-ipc-crimes-2017-onwards.csv')

# %%
df.head(4)
# Out:
#    id  year      state_name  state_code  district_name  district_code  \
# 0   0  2017  Andhra Pradesh          28  Ananthapuramu            502
# 1   1  2017  Andhra Pradesh          28       Chittoor            503
# 2   2  2017  Andhra Pradesh          28         Y.S.R.            504
# 3   3  2017  Andhra Pradesh          28  East Godavari            505
#
#   registration_circles  murder  clpbl_hmcrd_not_amt_murder  hit_and_run  ...  \
# 0            Anantapur   113.0                         4.0         50.0  ...
# 1             Chittoor    70.0                         5.0         36.0  ...
# 2             Cuddapah    88.0                        10.0         32.0  ...
# 3        East Godavari    69.0                        14.0        138.0  ...
#
#    ofnc_religion  cheating_impersonation  ofnc_mischief  arson  \
# 0            6.0                     4.0            9.0   38.0
# 1            0.0                     0.0            4.0    7.0
# ...

# %%
df.drop(['deaths_negl_rel_rail_acdnt','deaths_due_med_negnc','deaths_neg_civic_bodies','deaths_other_negnc','atmpt_cmmt_clpb_hmcrd','vlntrly_caus_simple_hurt','other_simple_hurt','grvus_hrt_dangerous_wepn'], axis=1,inplace=True)

# %%
df
# Out:
#         id  year         state_name  state_code  district_name  district_code  \
# 0        0  2017     Andhra Pradesh          28  Ananthapuramu            502
# 1        1  2017     Andhra Pradesh          28       Chittoor            503
# 2        2  2017     Andhra Pradesh          28         Y.S.R.            504
# 3        3  2017     Andhra Pradesh          28  East Godavari            505
# 4        4  2017     Andhra Pradesh          28  Ananthapuramu            502
# ...    ...   ...                ...         ...            ...            ...
# 5317  5317  2022  Jammu And Kashmir           1       Srinagar             13
# 5318  5318  2022  Jammu And Kashmir           1       Srinagar             13
# 5319  5319  2022  Jammu And Kashmir           1          Jammu              5
# 5320  5320  2022  Jammu And Kashmir           1       Srinagar             13
# 5321  5321  2022  Jammu And Kashmir           1          Jammu              5
#
# ...

# %%
df.drop(['atmpt_acid_attack','grvus_hrt_pub_srvnt_duty','other_grievous_hurt','wrngful_rest_cnfm','sex_hrrsmt_work_office_prms','sex_hrrsmt_pub_trnsprt_sys','sex_hrrsmt_shelter_homes','intnt_disrbe','missing_child_kidnpd','kidnp_abdctn_begging','kidnapping_for_ransom','import_girls_frgn_cntry','other_kidnp_abduc_sec_365_369'], axis=1,inplace=True)

# %%
df
# Out:
#         id  year         state_name  state_code  district_name  district_code  \
# 0        0  2017     Andhra Pradesh          28  Ananthapuramu            502
# 1        1  2017     Andhra Pradesh          28       Chittoor            503
# 2        2  2017     Andhra Pradesh          28         Y.S.R.            504
# 3        3  2017     Andhra Pradesh          28  East Godavari            505
# 4        4  2017     Andhra Pradesh          28  Ananthapuramu            502
# ...    ...   ...                ...         ...            ...            ...
# 5317  5317  2022  Jammu And Kashmir           1       Srinagar             13
# 5318  5318  2022  Jammu And Kashmir           1       Srinagar             13
# 5319  5319  2022  Jammu And Kashmir           1          Jammu              5
# 5320  5320  2022  Jammu And Kashmir           1       Srinagar             13
# 5321  5321  2022  Jammu And Kashmir           1          Jammu              5
#
# ...

# %%
df.drop(['exp_traf_person','sell_minors_prost','buy_minors_prost','atmpt_rape','unnatural_offences','ofnc_agnst_state_sedition','ofnc_agnst_pub_trnqul','rioting_communal_religious','rioting_industrial','rioting_caste_conflict','rioting_students','rioting_vigilants','rioting_money_dispute','rioting_water_dispute','rioting_land_property_dispute','rioting_family_disputes','rioting_enmity_rivalry','riot_elec_pwr_disp','riot_andolan_morcha','riot_polc_prsnl_gvt_srvnt','other_rioting','prmt_enmty_grps'], axis=1,inplace=True)

# %%
df
# Out:
#         id  year         state_name  state_code  district_name  district_code  \
# 0        0  2017     Andhra Pradesh          28  Ananthapuramu            502
# 1        1  2017     Andhra Pradesh          28       Chittoor            503
# 2        2  2017     Andhra Pradesh          28         Y.S.R.            504
# 3        3  2017     Andhra Pradesh          28  East Godavari            505
# 4        4  2017     Andhra Pradesh          28  Ananthapuramu            502
# ...    ...   ...                ...         ...            ...            ...
# 5317  5317  2022  Jammu And Kashmir           1       Srinagar             13
# 5318  5318  2022  Jammu And Kashmir           1       Srinagar             13
# 5319  5319  2022  Jammu And Kashmir           1          Jammu              5
# 5320  5320  2022  Jammu And Kashmir           1       Srinagar             13
# 5321  5321  2022  Jammu And Kashmir           1          Jammu              5
#
# ...

# %%
df.drop(['other_thefts','day_time_burglary','night_burglary','atmpt_dacoity_robbery','dacoity_with_murder','mkng_prprtn_assmbly_cmmttng_dcty','criminal_misappropriation','criminal_breach_of_trust','dsh_hon_rec_deal_stl_prop','counterfeit_coin','dsh_hon_rec_deal_stl_prop','counterfeit_coin','cntrfte_govt_stamp','ofnc_elections','other_frauds','disbnc_ordr_prmlgtd_pblc_srvnt','harboring_offender'], axis=1,inplace=True)

# %%
df
# Out:
#         id  year         state_name  state_code  district_name  district_code  \
# 0        0  2017     Andhra Pradesh          28  Ananthapuramu            502
# 1        1  2017     Andhra Pradesh          28       Chittoor            503
# 2        2  2017     Andhra Pradesh          28         Y.S.R.            504
# 3        3  2017     Andhra Pradesh          28  East Godavari            505
# 4        4  2017     Andhra Pradesh          28  Ananthapuramu            502
# ...    ...   ...                ...         ...            ...            ...
# 5317  5317  2022  Jammu And Kashmir           1       Srinagar             13
# 5318  5318  2022  Jammu And Kashmir           1       Srinagar             13
# 5319  5319  2022  Jammu And Kashmir           1          Jammu              5
# 5320  5320  2022  Jammu And Kashmir           1       Srinagar             13
# 5321  5321  2022  Jammu And Kashmir           1          Jammu              5
#
# ...

# %%
df.drop(['csng_hrt_rsh_nglgnt_drvng_pblc_wy','grvus_hrt_rsh_nglgnt_drvng','obstruction_pub_way','sale_obscene_books_objects','obscene_acts_songs_public_places','ofnc_religion','crcl_false_fake_news_rumours'], axis=1,inplace=True)

# %%
df
# Out:
#         id  year         state_name  state_code  district_name  district_code  \
# 0        0  2017     Andhra Pradesh          28  Ananthapuramu            502
# 1        1  2017     Andhra Pradesh          28       Chittoor            503
# 2        2  2017     Andhra Pradesh          28         Y.S.R.            504
# 3        3  2017     Andhra Pradesh          28  East Godavari            505
# 4        4  2017     Andhra Pradesh          28  Ananthapuramu            502
# ...    ...   ...                ...         ...            ...            ...
# 5317  5317  2022  Jammu And Kashmir           1       Srinagar             13
# 5318  5318  2022  Jammu And Kashmir           1       Srinagar             13
# 5319  5319  2022  Jammu And Kashmir           1          Jammu              5
# 5320  5320  2022  Jammu And Kashmir           1       Srinagar             13
# 5321  5321  2022  Jammu And Kashmir           1          Jammu              5
#
# ...

# %%
df.drop(['id','state_code','district_code'], axis=1,inplace=True)

# %%
df
# Out:
#       year         state_name  district_name  \
# 0     2017     Andhra Pradesh  Ananthapuramu
# 1     2017     Andhra Pradesh       Chittoor
# 2     2017     Andhra Pradesh         Y.S.R.
# 3     2017     Andhra Pradesh  East Godavari
# 4     2017     Andhra Pradesh  Ananthapuramu
# ...    ...                ...            ...
# 5317  2022  Jammu And Kashmir       Srinagar
# 5318  2022  Jammu And Kashmir       Srinagar
# 5319  2022  Jammu And Kashmir          Jammu
# 5320  2022  Jammu And Kashmir       Srinagar
# 5321  2022  Jammu And Kashmir          Jammu
#
#                                    registration_circles  murder  \
# 0                                             Anantapur   113.0
# 1                                              Chittoor    70.0
# 2                                              Cuddapah    88.0
# 3                                         East Godavari    69.0
# 4                                      Guntakal Railway    11.0
# ...

# %%
df = df.rename(columns={
    'clpbl_hmcrd_not_amt_murder': 'homicide'
})

# %%
df
# Out:
#       year         state_name  district_name  \
# 0     2017     Andhra Pradesh  Ananthapuramu
# 1     2017     Andhra Pradesh       Chittoor
# 2     2017     Andhra Pradesh         Y.S.R.
# 3     2017     Andhra Pradesh  East Godavari
# 4     2017     Andhra Pradesh  Ananthapuramu
# ...    ...                ...            ...
# 5317  2022  Jammu And Kashmir       Srinagar
# 5318  2022  Jammu And Kashmir       Srinagar
# 5319  2022  Jammu And Kashmir          Jammu
# 5320  2022  Jammu And Kashmir       Srinagar
# 5321  2022  Jammu And Kashmir          Jammu
#
#                                    registration_circles  murder  homicide  \
# 0                                             Anantapur   113.0       4.0
# 1                                              Chittoor    70.0       5.0
# 2                                              Cuddapah    88.0      10.0
# 3                                         East Godavari    69.0      14.0
# ...

# %%
df.to_csv("crime.csv",index=False)
